# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a><br><br>
#
# ¡Hola Sayde!
#
# Mi nombre es Juan Tellez. Un gusto conocerte, seré tu revisor en este proyecto.
#
# Cuando encuentre un error por primera vez, simplemente lo señalaré para que puedas identificarlo y corregirlo por tu cuenta. Además, a lo largo del notebook iré dejando algunas observaciones para mejorar tu dashboard, fortalecer tu análisis y comentar también tus interpretaciones sobre el tema.
#
# Si en esta primera orientación aún no logras resolver algún punto, en la próxima iteración te dejaré una pista más precisa y, cuando sea necesario, algunos ejemplos prácticos. La idea es que este proceso no sea solo una corrección, sino también una oportunidad para que desarrolles criterio como analista de datos.
#
# También estaré abierto a comentarios y discusiones sobre el tema.
#
# Encontrarás mis comentarios a continuación. Por favor, no los muevas, modifiques ni elimines.
#
# Puedes encontrar mis comentarios en cuadros verdes, amarillos o rojos como estos:
# </div>
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a><br><br>
#
# Éxito. Todo se ha hecho de forma exitosa.
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a><br><br>
#
# Observación. Algunas recomendaciones o ajustes no bloqueantes.
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a><br><br>
#
# Necesita arreglos. Este apartado necesita algunas correcciones. El trabajo no puede ser aceptado con comentarios rojos.
#
# </div>
#
# <div class="alert alert-block alert-info">
# <b>Respuesta de estudiante.</b> <a class="tocSkip"></a><br><br>
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Review General. (Iteración 1)</b> <a class="tocSkip"></a><br><br>
#
# Sayde, quería tomarme este espacio al inicio de tu proyecto para comentarte mis apreciaciones generales de esta iteración de tu entrega.
#
# Siempre me gusta comenzar dando la bienvenida al mundo de los datos a los estudiantes. Te deseo lo mejor en este camino y espero que consigas lograr tus objetivos. Personalmente me gusta compartir este consejo: está bien equivocarse. Es normal y, de hecho, es una de las mejores formas de aprender. Los errores te ayudan a descubrir detalles que no siempre se ven a primera vista, y esa experiencia es la que poco a poco te va formando como una mejor analista de datos.
#
# Ahora sí, yendo a esta entrega:
#
# Tu proyecto está muy bien encaminado y cumple con los elementos principales esperados para el dashboard inmobiliario. Se observa un tablero en Power BI con tres vistas claras: Overview Ejecutivo, Análisis Comercial y Análisis de Cohortes. También se evidencia un modelo relacional con tabla de hechos, dimensiones de propiedades/clientes, tabla de fechas y una tabla de medidas, lo cual le da una base técnica sólida al análisis.
#
# Me gustó especialmente que el dashboard presenta KPIs ejecutivos relevantes como Ingreso Total, Cantidad de Ventas, Ticket Promedio, Comisión Total y Crecimiento YoY. Además, la vista comercial compara ingresos por tipo de propiedad, canal de venta y segmento de cliente, y la matriz de cohortes permite analizar el comportamiento de los clientes en el tiempo. Esto muestra una buena comprensión de las preguntas de negocio del proyecto.
#
# Los puntos a reforzar son principalmente de documentación y pulido analítico: dejar más evidencia explícita de limpieza de datos en el notebook, revisar la consistencia entre títulos de visualizaciones y las métricas usadas cuando se habla de porcentajes, y sumar o hacer más visibles filtros/segmentadores para mejorar la interactividad del dashboard.
#
# En general, Sayde, esta entrega tiene calidad suficiente para ser aprobada. Las observaciones que te dejo son recomendaciones amarillas, no bloqueantes, orientadas a que el dashboard quede todavía más profesional, claro y fácil de auditar frente a un stakeholder real.
#
# Éxitos Sayde.
#
# Saludos.
# </div>

# %% [markdown]
# # 📊 Proyecto: Análisis Comercial Inmobiliario
#
# El sector inmobiliario necesita evaluar su **desempeño comercial** para comprender su crecimiento, rentabilidad y comportamiento de clientes.
#
# Se solicita construir un **dashboard ejecutivo** que permita analizar ventas, clientes y propiedades para apoyar decisiones estratégicas basadas en datos.

# %% [markdown]
# # 📂 Descripción de los Datasets
#
# 🔹 **hecho_ventas_propiedades**
# Tabla de hechos con las transacciones de venta (precio, cliente, propiedad, canal, fecha).
#
# 🔹 **dim_clientes**
# Información y segmentación de clientes.
#
# 🔹 **dim_propiedades**
# Características de las propiedades (tipo, tamaño, ubicación, etc).
#
# 🔹 **dim_fecha**
# Tabla calendario que deberá ser creada como parte del modelado.

# %% [markdown]
# # 🎯 Preguntas que el dashboard debe responder
#
# **Desempeño general**
#
# - ¿Cuál es el **ingreso total** generado por la empresa?
# - ¿Cuántas **propiedades se han vendido**?
# - ¿Cuál es el **precio promedio de venta**?
# - ¿Cuál es la **comisión total** generada por la empresa?
#
# **Análisis comercial**
#
# - ¿Qué **tipo de propiedad genera más ingresos**?
# - ¿Qué **segmento de clientes compra más propiedades**?
# - ¿Qué canal de venta **genera mayor ingresos**?
#
#
# **Análisis temporal**
#
# - ¿Cómo evolucionan las **ventas en el tiempo**?
# - ¿El negocio está **creciendo año contra año**?
# - ¿Cómo va el desempeño **acumulado del año actual (YTD)**?
#
# **Cohortes de clientes**
#
# - ¿Los clientes **vuelven a comprar** después de su primera compra?
# - ¿Qué **cohortes de clientes generan más compras/ingresos con el tiempo**?

# %% [markdown]
# ## 🧹 Paso 1: Limpieza de datos
#
# Antes del modelado, debes validar y depurar la información.
#
# ### Tipos de datos
#
# - `fecha_venta` debe estar en formato **Date**.
# - Los campos numéricos deben estar correctamente formateados.
# - `porcentaje_comision` debe estar en formato **porcentaje**.
#
# ### Valores nulos
#
# - Revisar valores **nulos** en las tablas.
# - Justificar si deben eliminarse o mantenerse.
#
# ### Duplicados
#
# - Validar que no existan duplicados en las claves primarias de:
#   - `dim_clientes`
#   - `dim_propiedades`

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a><br><br>
#
# La estructura general del dashboard muestra que los datos están funcionando correctamente: los campos monetarios se agregan, la fecha permite construir la tendencia mensual y las métricas principales responden en las visualizaciones. Eso es una buena señal para la calidad general de la preparación.
#
# Como recomendación para fortalecer la entrega, te sugiero dejar evidencia más explícita en el notebook sobre la limpieza de datos: validación de tipos, revisión de nulos y verificación de duplicados en las claves de <code>dim_clientes</code> y <code>dim_propiedades</code>. No necesariamente debes hacer una limpieza compleja si los datos ya están bien, pero sí conviene mostrar que lo verificaste.
#
# En un contexto profesional, esta documentación ayuda mucho porque permite que otra persona confíe en que los KPIs del dashboard no están afectados por valores nulos, tipos incorrectos o duplicados en dimensiones.
#
# </div>

# %% [markdown]
# ## 📅 Paso 2: Creación de tabla calendario
#
# Si vas a realizar el dashboard en **Power BI**, deberás crear una tabla calendario llamada **dim_fecha**.
#
# **Requisitos (solo para Power BI):**
#
# - Utilizar las funciones `CALENDAR` y `ADDCOLUMNS`.
# - El rango de fechas debe construirse dinámicamente desde la **fecha mínima** hasta la **fecha máxima** de ventas en `hecho_ventas_propiedades`.
# - Incluir como mínimo las siguientes columnas:
#   - Año
#   - Mes (nombre)
#   - Número de mes
#   - Año-Mes (formato `YYYY-MM`)
#
# > ⚠️ **Nota:**
# > Si utilizas **Tableau**, no necesitas crear esta tabla. Puedes usar directamente el campo `fecha_venta` de la tabla `hecho_ventas_propiedades`, ya que Tableau genera automáticamente las jerarquías de fecha.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a><br><br>
#
# Buen trabajo con la base temporal del proyecto. En la captura del modelo se observa una tabla <code>dim_fecha</code> con campos como <code>Date</code>, <code>Año</code>, <code>Mes</code> y <code>Año-Mes</code>, lo cual permite trabajar correctamente los análisis por periodo.
#
# Esto es importante porque el dashboard no solo muestra ventas acumuladas, sino también evolución temporal y crecimiento YoY. Tener una tabla de fechas separada ayuda a que las medidas de inteligencia de tiempo sean más confiables y escalables.
#
# Como recomendación menor, valida que <code>Año-Mes</code> esté ordenado por una fecha real o por un número de mes, para evitar problemas de orden cuando se usen más años o periodos.
#
# </div>

# %% [markdown]
# ## 🧩 Paso 3: Modelado de datos
#
# ### Modelo requerido: Esquema estrella
#
# El modelo debe estructurarse en formato estrella:
#
# - `hecho_ventas_propiedades` como tabla central.
# - Tablas dimensionales conectadas:
#   - `dim_clientes`
#   - `dim_propiedades`
#   - `dim_fecha` (creada por ti, en caso de que aplique)
#
# Requisitos de las relaciones:
#
# - Cardinalidad **uno a muchos (1:*)**
# - Dirección de filtro **simple (single)**
# - Relaciones basadas en las claves correctas
# - Todas las relaciones deben estar **activas**

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a><br><br>
#
# Muy buen avance en el modelado de datos. En la captura se observa una estructura tipo estrella, con <code>hecho_ventas_propiedades</code> como tabla principal y dimensiones separadas para propiedades, clientes y fecha. También se ve una tabla de medidas, lo cual es una buena práctica en Power BI para mantener el modelo más ordenado.
#
# Este punto fortalece bastante el proyecto porque un dashboard ejecutivo depende de que las relaciones funcionen correctamente. Cuando la tabla de hechos está conectada a dimensiones por claves adecuadas, los filtros por fecha, ciudad, tipo de propiedad o cliente pueden afectar las métricas de forma consistente.
#
# Te recomiendo únicamente revisar que todas las relaciones estén activas, con cardinalidad 1:* desde las dimensiones hacia la tabla de hechos y dirección de filtro simple. Por lo visible, la estructura está muy bien planteada.
#
# </div>

# %% [markdown]
# ## 📊 Paso 4: Creación de medidas
#
# En este paso deberás crear las **medidas necesarias para responder las preguntas de negocio del dashboard**.
#
# Las medidas pueden implementarse en **Power BI (DAX)** o como **Calculated Fields en Tableau**.
#
# ---
#
# ### 4.1 🔹 Medidas base
#
# Crear como mínimo las siguientes medidas:
#
# - **Ingreso Total** (suma del `precio_venta`)
# - **Cantidad de Ventas**
# - **Ticket Promedio**
# - **Comisión Total**
#
# Estas métricas permitirán analizar el desempeño general del negocio.
#
# ---
#
# ### 4.2 🔹 Medidas con contexto de filtro
#
# Debes crear **al menos 2 medidas** que modifiquen el contexto de filtro.
#
# En este caso se utilizarán **medidas de participación (%)**, que permiten entender **qué proporción del ingreso total aporta cada categoría**.
#
# Las medidas que deben construirse son:
#
# - **Participación de ingresos por tipo de propiedad**
# - **Participación de ingresos por canal de venta**
# - **Participación de ingresos por segmento de cliente**
#
# Para ello:
# - Modifica el contexto de filtro con las funciones propias de cada herramienta
#   - En Power BI, usa `CALCULATE`
#   - En Tableau, usa expresiones como `FIXED` (LOD)
#
# Elimina el filtro de la dimensión correspondiente para obtener el total
#
# Asegúrate de que el denominador represente el total sin el filtro de la categoría, mientras que el numerador sí lo conserva.
#
# Estas medidas se utilizarán principalmente como **tooltip o etiqueta adicional en los gráficos** del dashboard para complementar el análisis.
#
# ---
#
# ### 4.3 🔹 Inteligencia de tiempo
#
# Utilizando la tabla **`dim_fecha`** (Power BI) o las funciones de fecha en Tableau, debes crear al menos 2 de las siguientes medidas:
#
# - **Ventas Year to Date (YTD)**
# - **Ventas Month to Date (MTD)**
# - **Ventas del año anterior**
# - **Crecimiento Year over Year (YoY)**
#
# Estas métricas permitirán analizar la evolución del negocio en el tiempo.
#
# ---
#
# ### 4.4 🔹 Medidas para análisis de cohortes
#
# Debes crear cálculos que permitan analizar **si los clientes vuelven a comprar después de su primera compra**.
#
# ⚠️ Estos cálculos deben crearse como **columnas calculadas**, no como medidas.
# Todas deben crearse en la tabla **`hecho_ventas_propiedades`**.
#
# Debes crear como mínimo:
#
# - **Primera compra por cliente** → fecha mínima de compra de cada cliente.
# - **Mes Cohorte** → mes en que el cliente realizó su **primera compra** (mes de adquisición).
# - **Mes Venta** → mes en que ocurre cada transacción. Este campo permite identificar **cuándo el cliente vuelve a comprar** después de su primera compra.
#
# Estos cálculos permitirán construir una **matriz de cohortes** donde:
#
# - **Filas** representen el **mes de cohorte**
# - **Columnas** representen el **mes de venta**
# - **Valores** muestren **cantidad de ventas o ingresos**
#
# ---

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a><br><br>
#
# Buen trabajo creando y usando medidas de negocio. En el dashboard se observan claramente los KPIs principales: Ingreso Total, Cantidad de Ventas, Ticket Promedio, Comisión Total y Crecimiento YoY. Además, en la tabla de medidas aparecen cálculos asociados a participación por canal, segmento y tipo de propiedad.
#
# Esto es muy positivo porque las medidas convierten el modelo en información accionable. Los stakeholders pueden leer rápidamente cuánto se vendió, cuántas operaciones hubo, cuál fue el ticket promedio, cuánto se generó en comisión y cómo cambió el negocio frente al periodo anterior.
#
# Como recomendación de pulido, valida la consistencia visual entre las medidas de porcentaje y los gráficos. En la vista comercial, algunos títulos dicen “% Ingreso”, pero el eje se muestra en valores monetarios. Puedes resolverlo de dos formas: usar la medida porcentual en el visual o cambiar el título a “Ingreso por...” para que el gráfico comunique exactamente lo que está mostrando.
#
# </div>

# %% [markdown]
# ## 📊 Paso 5: Estructura del reporte
#
# El dashboard debe contener **mínimo tres páginas**.
#
# ---
#
# ### 5.1 1️⃣ Overview Ejecutivo
#
# Debe mostrar **el desempeño general del negocio**.
#
# Incluir minimo 4 KPIs:
#
# - **KPIs principales**
#   - Ingreso Total
#   - Cantidad de Ventas
#   - Ticket Promedio
#   - Comisión Total
#
# - **Tendencia de ventas en el tiempo**
#
# - **Ingresos o ventas por ciudad**
#
# - **Crecimiento Year over Year (YoY)**
#
# ---
#
# ### 5.2 2️⃣ Análisis Comercial
#
# Debe analizar **qué productos, canales y clientes generan más ingresos**.
#
# Incluir:
#
# - **Ingreso por tipo de propiedad**
# - **Ventas o ingresos por canal de venta**
# - **Ventas o ingresos por segmento de cliente**
# - **Tabla con formato condicional (colores semáforo)**
#   Sugerencia de campos:
#   - tipo_propiedad
#   - Ingreso Total
#   - Cantidad Ventas
#   - Ticket Promedio
#   Aplicar **formato condicional** para resaltar las categorías con mayor desempeño.
#
# Se recomienda usar **tooltips con medidas de participación (%)**.
#
# ---
#
# ### 5.3 3️⃣ Análisis de Cohortes
#
# Debe analizar **recurrencia de clientes**.
#
# Incluir:
#
# - **Matriz de cohortes**
#   - Filas → Mes Cohorte
#   - Columnas → Mes Venta
#   - Valores → Cantidad Ventas o Ingreso Total
#
# Esto permitirá observar **si los clientes vuelven a comprar y comparar cohortes en el tiempo**.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a><br><br>
#
# La estructura del reporte está muy bien lograda. Se observan tres páginas principales: Overview Ejecutivo, Análisis Comercial y Análisis de Cohortes. Esta organización es adecuada porque permite pasar de una lectura general del negocio a un análisis más detallado por categorías y luego a una mirada de recurrencia o comportamiento en el tiempo.
#
# El Overview Ejecutivo presenta KPIs claros, tendencia mensual, comparación por ciudad y crecimiento YoY. La vista de Análisis Comercial compara tipo de propiedad, canal de venta y segmento de cliente, además de incluir una tabla con formato condicional. La vista de Cohortes muestra una matriz por mes de cohorte y mes de venta, lo cual responde al objetivo de analizar comportamiento posterior a la primera compra.
#
# Este diseño es destacable porque se siente pensado para stakeholders: primero resume, luego explica y finalmente permite profundizar en patrones de comportamiento.
#
# </div>

# %% [markdown]
# ## 📝Paso 6:  Resumen Ejecutivo
#
# Hallazgos clave
# - El ingreso total del periodo (2023–2024) fue de $6,012,502,170 generado
#   por 8,500 ventas.
# - El tipo de propiedad que genera mayor ingreso es Casa, con $2,240,535,304
#   (37% del total), seguido de Comercial y Departamento.
# - La ciudad con mayor volumen de ingresos es Ciudad de México ($3,242,231,285),
#   superando a Bogotá ($2,770,270,885).
# - El canal de venta más eficiente en términos de ingresos es Corredor, que
#   concentra el 73% del ingreso total ($4,379,990,279) frente a Directo.
#
# Métricas principales
# - Ingreso Total: $6,012,502,170
# - Cantidad de Ventas: 8,500
# - Ticket Promedio: $707,353
# - Comisión Total: $200,627,166
# - Crecimiento YoY (2024 vs 2023): 11.14%
#
# Insights accionables
# - El segmento de clientes Primera vez concentra la mayor parte del ingreso
#   ($3,783,579,998, 63%), seguido de Inversionista y Alto patrimonio.
# - Los clientes adquiridos en la cohorte de marzo 2023 muestran la mayor
#   recurrencia e ingreso generado en el tiempo, junto con abril 2023.
# - El 77.13% de los clientes ha realizado más de una compra, lo que indica
#   una tasa de recompra sólida para el negocio.
# - Las ventas muestran un crecimiento de 11.14% YoY, señal de un negocio en
#   expansión.
#
# Recomendaciones estratégicas
# - Priorizar la comercialización de propiedades tipo Casa, dado que genera
#   el mayor ingreso individual por categoría.
# - Fortalecer el canal Corredor, que presenta la mayor participación en el
#   revenue (73%), posiblemente incrementando incentivos o comisiones para
#   corredores de alto desempeño.
# - Diseñar estrategias de fidelización dirigidas al segmento Primera vez,
#   buscando convertirlos en compradores recurrentes o inversionistas.
# - Replicar las tácticas de adquisición usadas en las cohortes de inicios
#   de 2023 (marzo y abril), que mostraron mayor recompra e ingreso sostenido
#   en el tiempo.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios._

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor. (Iteración 1)</b> <a class="tocSkip"></a><br><br>
#
# Muy buen trabajo con el resumen ejecutivo. Incluyes cifras concretas como ingreso total, cantidad de ventas, ticket promedio, comisión total y crecimiento YoY. También identificas elementos clave del negocio: Casa como tipo de propiedad con mayor ingreso, Ciudad de México como ciudad líder, Corredor como canal principal y Primera vez como segmento más relevante.
#
# Este punto es fuerte porque no te quedas solo en describir gráficos, sino que traduces los resultados en hallazgos e insights. Esa es una habilidad muy importante en proyectos de análisis de datos, porque el valor para negocio aparece cuando los números se conectan con decisiones.
#
# Como recomendación menor, podrías separar visualmente el resumen en tres bloques: hallazgos, insights y recomendaciones. El contenido ya está, pero esa estructura ayudaría a que un stakeholder lo lea más rápido.
#
# </div>

# %% [markdown]
# ## 🚀 Entrega Final
#
# Comparte el acceso a tu proyecto final para revisión.
#
# Puedes entregar el proyecto utilizando **Power BI o Tableau**.
#
# Incluye **uno de los siguientes**:
#
# - 🔗 Link público del dashboard publicado en **Power BI Service o Tableau Public / Tableau Cloud**
# - 🔗 Link de **Google Drive o OneDrive** con el archivo `.pbix` del proyecto
# - ✅ Confirmación de que el archivo `.pbix` fue subido según las instrucciones del curso
#
# ### 📎 Enlace del proyecto
# ✏️ (Pega aquí tu link o escribe "Subi mi proyecto a la plataforma")

# %%
# (Pega aquí tu link)
https://drive.google.com/drive/folders/1f9RfQUofD2aQUWGuiqSxq3ulANKI4nmL?usp=sharing
https://app.powerbi.com/groups/me/reports/94868d02-4099-4c6c-8356-41b4d66ee276?ctid=030e951d-6efd-42f5-8427-bab632cf8010&pbi_source=linkShare
